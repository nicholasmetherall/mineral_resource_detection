# %%
import os
import sys
sys.path.insert(0, '..')

import pandas as pd
import geopandas as gpd
import numpy as np
import rioxarray
import xarray as xr
from ipyleaflet import Map, LayersControl, basemaps

import depal as dep
# from model import add_image_values, get_model_prediction, get_overlay

import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.insert(0, '..')
import depal as dep
import warnings
warnings.filterwarnings('ignore')

# %%
from pystac_client import Client

# %%
dep.init()
# Out:
# Initiating DEPAL...
# <Client: 'tcp://127.0.0.1:40093' processes=4 threads=16, memory=64.00 GiB>
# /user/nicholasm@spc.int/proxy/34785/status

# %%
# installations 
pip3 install urlpath
# Out:
#   Cell In[8], line 2
#     pip3 install urlpath
#          ^
# SyntaxError: invalid syntax

# %%
pip3 install retry

# %%
from odc.stac import load
from pystac import Item

url_template = "https://deppcpublicstorage.blob.core.windows.net/output/dep_s2_mangroves/0-0-2/FJ/031/2022/dep_s2_mangroves_FJ_031_2022.stac-item.json"

# %%
items = []

for year in range(2019,2022):
    url = url_template.format(year=year)
    item = Item.from_file(url)
    items.append(item)

print(len(items))

# %%
data = load(items, chunks={})
data

# %%
# aoi = [3110943,-1999061, 3127224,-1987145]
# aoi = [177.96704,-17.76615,178.07057,-17.68005]
# aoi = [177.0, -19.0, 178.0, -18.0]

# aoi = [177.600308, -17.422541, 177.755366, -17.508569] 
aoi = [177.591934,-17.526343,177.739563,-17.426084]

# %%
# data = load(items, bbox=aoi, crs="epsg:3832", resolution=30, chunks={})
# data = load(items, bbox=aoi, crs="epsg:3832", resolution=10, chunks={})
data = load(items, bbox=aoi, crs="epsg:3832", resolution=10)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # data = load(items, bbox=aoi, crs="epsg:3832", resolution=30, chunks={})
#       2 # data = load(items, bbox=aoi, crs="epsg:3832", resolution=10, chunks={})
# ----> 3 data = load(items, bbox=aoi, crs="epsg:3832", resolution=10)
#       4 data
#
# NameError: name 'load' is not defined

# %%
# For years 2017 to 2023
print(len(data))

# %%
# For years 2017 to 2023
data.closed.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # For years 2017 to 2023
# ----> 2 data.closed.values
#
# NameError: name 'data' is not defined

# %%
import depal as dep

# %%
.explore()
# Out:
#   Cell In[12], line 1
#     .explore()
#     ^
# SyntaxError: invalid syntax

# %%
data.mangroves.plot(cmap="Greens", col_wrap=4, size=6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.mangroves.plot(cmap="Greens", col_wrap=4, size=6)
#
# NameError: name 'data' is not defined

# %%
data.ndvi.plot(cmap="Blues")

# %%
# # import bbox-visualizer 
# import bbox_visualizer as bbv

# %%
pip install python_ms

mangrove = [ms.ndvi(x.sel(band="nir"), x.sel(band="red")) for x in data]

ndvi = xr.concat(ndvi_aggs, dim="time")

ndvi.plot.imshow(x="x", y="y", cmap="RdYlGn"); #RdYlGn #viridis
# Out:
#   Cell In[30], line 1
#     pip install python_ms
#         ^
# SyntaxError: invalid syntax

# %%
# data.closed.plot(cmap="Blues", col="time")

# %%
# mangroves = [ms.ndvi(x.sel(band="nir"), x.sel(band="red")) for x in data]

# ndvi = xr.concat(ndvi_aggs, dim="time")

# ndvi.plot.imshow(x="x", y="y", col="time", col_wrap=5, cmap="RdYlGn"); #RdYlGn #viridis

# %%
# from pystac_client import Client

# url = "//deppcpublicstorage.blob.core.windows.net/"

# client = Client.open(url)

# start_date = "2020-01-01"
# end_date = "2023-01-01"

# results = client.search(collections=["dep_s2_mangroves"], bbox = [177.96704,-17.76615,178.07057,-17.68005], datetime=f"{start_date}/{end_date}")

# items = results.get_all_items()
# print(len(items))

# %%
from pystac_client import Client

# url = "https://stac.staging.auspatious.com/"
url = "https://maps.staging.digitalearthpacific.org/"

client = Client.open(url)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[57], line 6
#       3 # url = "https://stac.staging.auspatious.com/"
#       4 url = "https://maps.staging.digitalearthpacific.org/"
# ----> 6 client = Client.open(url)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac_client/client.py:166, in Client.open(cls, url, headers, parameters, ignore_conformance, modifier, request_modifier, stac_io, timeout)
#      94 @classmethod
#      95 def open(
#      96     cls,
#    (...)
#     104     timeout: Optional[Timeout] = None,
#     105 ) -> "Client":
#     106     """Opens a STAC Catalog or API
#     107     This function will read the root catalog of a STAC Catalog or API
#     108
#    (...)
#     164         catalog : A :class:`Client` instance for this Catalog/API
#     165     """
# --> 166     client: Client = cls.from_file(
#     167         url,
# ...

# %%
# Build a query with the set parameters
query = client.search(collections=["dep_s2_mangroves"], bbox=[177.96704,-17.76615,178.07057,-17.68005], datetime=f"{start_date}/{end_date}"
)

# Search the STAC catalog for all items matching the query
items = list(query.get_items())
print(f"Found: {len(items):d} datasets")

# %%
items.get_all_items()

# %%
data = load(items, chunks={}, bbox = [177.96704,-17.76615,178.07057,-17.68005], resolution=300)
data

# %%
data.time.values
# Out:
# array(['2022-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
items = []

for year in range(2015,2023):
    url = url_template.format(year=year)
    item = Item.from_file(url)
    items.append(item)

print(len(items))
# Out:
# 8

# %%
data = load(items, chunks={})
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8278, x: 3847, time: 1)
# Coordinates:
#   * y            (y) float64 -1.808e+06 -1.808e+06 ... -1.891e+06 -1.891e+06
#   * x            (x) float64 3.338e+06 3.338e+06 ... 3.377e+06 3.377e+06
#     spatial_ref  int32 3832
#   * time         (time) datetime64[ns] 2022-01-01
# Data variables:
#     ndvi         (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     mangroves    (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     regular      (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     closed       (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>

# %%
data = load(items, chunks={})
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8278, x: 3847, time: 1)
# Coordinates:
#   * y            (y) float64 -1.808e+06 -1.808e+06 ... -1.891e+06 -1.891e+06
#   * x            (x) float64 3.338e+06 3.338e+06 ... 3.377e+06 3.377e+06
#     spatial_ref  int32 3832
#   * time         (time) datetime64[ns] 2022-01-01
# Data variables:
#     ndvi         (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     mangroves    (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     regular      (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     closed       (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>

# %%
data.asset.plot(cmap="Blues")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data.asset.plot(cmap="Blues")
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'asset'

# %%
aoi = [177.058036, -18.365573, 178.9015685571753, -17.20918079421351]

# %%
data = load(items, chunks={}, aoi = [177.058036, -18.365573, 178.9015685571753, -17.20918079421351])
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8278, x: 3847, time: 1)
# Coordinates:
#   * y            (y) float64 -1.808e+06 -1.808e+06 ... -1.891e+06 -1.891e+06
#   * x            (x) float64 3.338e+06 3.338e+06 ... 3.377e+06 3.377e+06
#     spatial_ref  int32 3832
#   * time         (time) datetime64[ns] 2022-01-01
# Data variables:
#     ndvi         (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     mangroves    (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     regular      (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>
#     closed       (time, y, x) float32 dask.array<chunksize=(1, 8278, 3847), meta=np.ndarray>

# %%
# data.asset.plot(cmap="Blues", col="time")

# %%
# data.asset.plot(cmap="Blues", col="time", col_wrap=4, size=6)

# %%
data.asset.plot(cmap="Blues")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 data.asset.plot(cmap="Blues")
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'asset'

# %%
data.asset.plot(cmap="Blues", col="time")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data.asset.plot(cmap="Blues", col="time")
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'asset'

# %%
wofs = [ms.ndvi(x.sel(band="nir"), x.sel(band="red")) for x in data]

ndvi = xr.concat(ndvi_aggs, dim="time")

ndvi.plot.imshow(x="x", y="y", col="time", col_wrap=5, cmap="RdYlGn"); #RdYlGn #viridis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 wofs = [ms.ndvi(x.sel(band="nir"), x.sel(band="red")) for x in data]
#       3 ndvi = xr.concat(ndvi_aggs, dim="time")
#       5 ndvi.plot.imshow(x="x", y="y", col="time", col_wrap=5, cmap="RdYlGn"); #RdYlGn #viridis
#
# Cell In[46], line 1, in <listcomp>(.0)
# ----> 1 wofs = [ms.ndvi(x.sel(band="nir"), x.sel(band="red")) for x in data]
#       3 ndvi = xr.concat(ndvi_aggs, dim="time")
#       5 ndvi.plot.imshow(x="x", y="y", col="time", col_wrap=5, cmap="RdYlGn"); #RdYlGn #viridis
#
# NameError: name 'ms' is not defined

# %%
# aoi = [3110943,-1999061, 3127224,-1987145]
aoi = [177.96704,-17.76615,178.07057,-17.68005]

# %%
# data = load(items, bbox=aoi, crs="epsg:3832", resolution=30, chunks={})
data = load(items, bbox=aoi, crs="epsg:3832", resolution=30, chunks={})
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 335, x: 386, time: 1)
# Coordinates:
#   * y            (y) float64 -1.987e+06 -1.987e+06 ... -1.997e+06 -1.997e+06
#   * x            (x) float64 3.113e+06 3.113e+06 ... 3.125e+06 3.125e+06
#     spatial_ref  int32 3832
#   * time         (time) datetime64[ns] 2022-01-01
# Data variables:
#     ndvi         (time, y, x) float32 dask.array<chunksize=(1, 335, 386), meta=np.ndarray>
#     mangroves    (time, y, x) float32 dask.array<chunksize=(1, 335, 386), meta=np.ndarray>
#     regular      (time, y, x) float32 dask.array<chunksize=(1, 335, 386), meta=np.ndarray>
#     closed       (time, y, x) float32 dask.array<chunksize=(1, 335, 386), meta=np.ndarray>

# %%
data.time.values
# Out:
# array(['2022-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
data.asset.plot(cmap="Blues", col="time", col_wrap=4, size=6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 data.asset.plot(cmap="Blues", col="time", col_wrap=4, size=6)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'asset'

# %%
# DEP / depal approach

dep.explore()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 3
#       1 # DEP / depal approach
# ----> 3 dep.explore()
#
# AttributeError: module 'depal' has no attribute 'explore'

# %%
# ODC DEA approach
display_map()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 # ODC DEA approach
# ----> 2 display_map()
#
# NameError: name 'display_map' is not defined

# %%
import leafmap.leafmap as leafmap

# %%
leafmap
# Out:
# <module 'leafmap.leafmap' from '/srv/conda/envs/notebook/lib/python3.11/site-packages/leafmap/leafmap.py'>

# %%
import leafmap
m = leafmap.Map(center=(85, 33), zoom=4)
m
# Out:
# Map(center=[85, 33], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…
