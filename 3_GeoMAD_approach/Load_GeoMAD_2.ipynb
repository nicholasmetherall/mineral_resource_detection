# %%
# Run then comment out
# pip install odc-algo

# %%
# Dependencies
import stackstac
import pystac_client

from pystac_client import Client
from odc.stac import load
import geopandas as gpd

import planetary_computer as pc

import numpy as np
import xarray as xr


import matplotlib.pyplot as plt

import geopandas as gpd
import json
import rasterio.features
from pystac.extensions.projection import ProjectionExtension as proj

import xrspatial.multispectral as ms
from xrspatial.convolution import calc_cellsize, circle_kernel, convolution_2d
from xrspatial.focal import mean, focal_stats, hotspots

from dask.distributed import Client, progress

import depal as dep

# Try this if installing both dask and pystac
#  from pystac_client import Client as PystacClient and then open the catalog with that PystacClient.open().

# %%
# client = Client.open("https://stac.staging.digitalearthpacific.org")
from pystac_client import Client as PystacClient 
PystacClient.open("https://stac.staging.digitalearthpacific.org")
# Out:
# <Client id=dep-stac-staging>

# %%
   import depal as dep
   import warnings
   warnings.filterwarnings('ignore')
   dep.init()
# Out:
# Initiating DEPAL...
# <Client: 'tcp://127.0.0.1:34771' processes=4 threads=16, memory=64.00 GiB>
# /user/nicholasm@spc.int/proxy/8787/status

# %%
# grid = (gpd.read_file(
#         "https://raw.githubusercontent.com/digitalearthpacific/dep-grid/master/grid_pacific.geojson"
#     )
#     .astype({"tile_id": str, "country_code": str})
#     .set_index(["tile_id", "country_code"], drop=False))

# client = Client.open("https://stac.staging.digitalearthpacific.org") # does not work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 7
#       1 # grid = (gpd.read_file(
#       2 #         "https://raw.githubusercontent.com/digitalearthpacific/dep-grid/master/grid_pacific.geojson"
#       3 #     )
#       4 #     .astype({"tile_id": str, "country_code": str})
#       5 #     .set_index(["tile_id", "country_code"], drop=False))
# ----> 7 client = Client.open("https://stac.staging.digitalearthpacific.org") # does not work
#
# AttributeError: type object 'Client' has no attribute 'open'

# %%
region_code = "64,21"

cell = grid.loc[[(region_code)]]
cell.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fac6f60e86ea5e8b30fa8f426a336b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fac6f60e86ea5e8b30fa8f426a336b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fac6f60e86ea5e8b30fa8f426a336b6 = L.map(
#                 &quot;map_7fac6f60e86ea5e8b30fa8f426a336b6&quot;,
#                 {
#                     center: [-17.238463876449977, 178.67422386909513],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7fac6f60e86ea5e8b30fa8f426a336b6);
#
#
#
#
#
#             var tile_layer_9798ba62bcbcf8543f9715dec3a3cd1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fac6f60e86ea5e8b30fa8f426a336b6);
#
#
#             map_7fac6f60e86ea5e8b30fa8f426a336b6.fitBounds(
#                 [[-17.65281330691017, 178.24303253271776], [-16.824114445989785, 179.1054152054725]],
#                 {}
#             );
#
#
#         function geo_json_893652c5adb94cd6d058ddabfcc61696_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_893652c5adb94cd6d058ddabfcc61696_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_893652c5adb94cd6d058ddabfcc61696_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_893652c5adb94cd6d058ddabfcc61696_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_893652c5adb94cd6d058ddabfcc61696_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_893652c5adb94cd6d058ddabfcc61696.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_893652c5adb94cd6d058ddabfcc61696_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_893652c5adb94cd6d058ddabfcc61696 = L.geoJson(null, {
#                 onEachFeature: geo_json_893652c5adb94cd6d058ddabfcc61696_onEachFeature,
#
#                 style: geo_json_893652c5adb94cd6d058ddabfcc61696_styler,
#                 pointToLayer: geo_json_893652c5adb94cd6d058ddabfcc61696_pointToLayer
#         });
#
#         function geo_json_893652c5adb94cd6d058ddabfcc61696_add (data) {
#             geo_json_893652c5adb94cd6d058ddabfcc61696
#                 .addData(data)
#                 .addTo(map_7fac6f60e86ea5e8b30fa8f426a336b6);
#         }
#             geo_json_893652c5adb94cd6d058ddabfcc61696_add({&quot;bbox&quot;: [178.24303253271776, -17.65281330691017, 179.1054152054725, -16.824114445989785], &quot;features&quot;: [{&quot;bbox&quot;: [178.24303253271776, -17.65281330691017, 179.1054152054725, -16.824114445989785], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[178.24303253271776, -16.824114445989785], [178.24303253271776, -17.65281330691017], [179.1054152054725, -17.65281330691017], [179.1054152054725, -16.824114445989785], [178.24303253271776, -16.824114445989785]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;(\u002764,21\u0027, \u0027FJ\u0027)&quot;, &quot;properties&quot;: {&quot;bbox&quot;:

# %%
items = list(client.search(collections=["dep_ls_geomad"], intersects=cell.buffer(-0.001).geometry[0]).items())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 items = list(client.search(collections=["dep_ls_geomad"], intersects=cell.buffer(-0.001).geometry[0]).items())
#
# NameError: name 'client' is not defined

# %%
data = load(items, geometry=cell, chunks={})
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data = load(items, geometry=cell, chunks={})
#       2 data
#
# NameError: name 'items' is not defined

# %%
# ML Code goes here
results = predict(data, model, thing)

plot("the magic happens")

# %%
items = [pc.sign(item).to_dict() for item in search.get_items()]
print(len(items))

# %%
client = Client.open("https://stac.staging.digitalearthpacific.org")
